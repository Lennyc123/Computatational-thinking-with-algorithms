# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

# %%
input_size = [100, 250, 500, 750, 1000, 1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000]

bubbleBenchmarks = [1.2, 7.101, 34.703, 69.105, 121.309, 189.214 ,789.458 ,1748.333, 3231.896, 5049.497, 7503.218, 10370.583, 13146.455]
selectionBenchmarks = [0.4 ,2.600 ,12.201, 26.602, 46.904,  73.707, 293.522,  650.850, 1198.191, 1829.037, 2770.859, 4291.227, 5107.924]
mergeBenchmarks = [0.2, 0.900, 2.700, 3.000, 4.500, 5.600, 12.601, 19.900, 26.800, 42.003, 47.603, 54.006, 70.404]
heapBenchmarks = [0.2, 1.100, 2.500, 4.700, 6.100, 8.301, 17.601, 27.401, 37.003, 48.904, 63.206, 82.506, 94.007]
countBenchmarks = [0.1, 0.400, 0.500, 0.500, 0.700, 1.000, 1.900, 2.500, 3.801, 5.900, 5.600, 7.901, 7.302]

plt.plot(input_size, bubbleBenchmarks,'o-', label='Bubble Sort')
plt.plot(input_size, selectionBenchmarks,'o-', label='Selection Sort')
plt.plot(input_size, mergeBenchmarks,'o-', label='Merge Sort')
plt.plot(input_size, heapBenchmarks,'o-', label='Heap Sort')
plt.plot(input_size, countBenchmarks,'o-', label='Counting Sort')

plt.title('An Empirical Analysis of the Selected Sorting Algorithms')
plt.legend()
plt.xlabel('Input size n')
plt.ylabel('Running time (milliseconds)')
plt.grid(True)

plt.savefig('linegraph_sorting_algorithms')
plt.show()

# %%
input_size = [100, 250, 500, 750, 1000, 1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000]

#bubbleBenchmarks = [1.2, 7.101, 34.703, 69.105, 121.309, 189.214 ,789.458 ,1748.333, 3231.896, 5049.497, 7503.218, 10370.583, 13146.455]
#selectionBenchmarks = [0.4 ,2.600 ,12.201, 26.602, 46.904,  73.707, 293.522,  650.850, 1198.191, 1829.037, 2770.859, 4291.227, 5107.924]
mergeBenchmarks = [0.2, 0.900, 2.700, 3.000, 4.500, 5.600, 12.601, 19.900, 26.800, 42.003, 47.603, 54.006, 70.404]
heapBenchmarks = [0.2, 1.100, 2.500, 4.700, 6.100, 8.301, 17.601, 27.401, 37.003, 48.904, 63.206, 82.506, 94.007]
countBenchmarks = [0.1, 0.400, 0.500, 0.500, 0.700, 1.000, 1.900, 2.500, 3.801, 5.900, 5.600, 7.901, 7.302]

#plt.plot(input_size, bubbleBenchmarks,'o-', label='Bubble Sort')
#plt.plot(input_size, selectionBenchmarks,'o-', label='Selection Sort')
plt.plot(input_size, mergeBenchmarks,'go-', label='Merge Sort')
plt.plot(input_size, heapBenchmarks,'ro-', label='Heap Sort')
plt.plot(input_size, countBenchmarks, color='#9467bd', marker='o', linestyle='solid', label='Counting Sort')

plt.title('An Empirical Analysis of the Selected Sorting Algorithms')
plt.legend()
plt.xlabel('Input size n')
plt.ylabel('Running time (milliseconds)')
plt.grid(True)

plt.savefig('3 linegraph_sorting_algorithms')
plt.show()

# %%
input_size = [100, 250, 500, 750, 1000, 1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000]

bubbleBenchmarks = [1.2, 7.101, 34.703, 69.105, 121.309, 189.214 ,789.458 ,1748.333, 3231.896, 5049.497, 7503.218, 10370.583, 13146.455]
selectionBenchmarks = [0.4 ,2.600 ,12.201, 26.602, 46.904,  73.707, 293.522,  650.850, 1198.191, 1829.037, 2770.859, 4291.227, 5107.924]
mergeBenchmarks = [0.2, 0.900, 2.700, 3.000, 4.500, 5.600, 12.601, 19.900, 26.800, 42.003, 47.603, 54.006, 70.404]
heapBenchmarks = [0.2, 1.100, 2.500, 4.700, 6.100, 8.301, 17.601, 27.401, 37.003, 48.904, 63.206, 82.506, 94.007]
countBenchmarks = [0.1, 0.400, 0.500, 0.500, 0.700, 1.000, 1.900, 2.500, 3.801, 5.900, 5.600, 7.901, 7.302]

plt.plot(input_size, bubbleBenchmarks,'o-', label='Bubble Sort')
plt.plot(input_size, selectionBenchmarks,'o-', label='Selection Sort')
plt.plot(input_size, mergeBenchmarks,'o-', label='Merge Sort')
plt.plot(input_size, heapBenchmarks,'o-', label='Heap Sort')
plt.plot(input_size, countBenchmarks,'o-', label='Counting Sort')

plt.yscale('log')
plt.title('(Y Scale log) An Empirical Analysis of the Selected Sorting Algorithms')
plt.legend()
plt.xlabel('Input size n')
plt.ylabel('Running time (milliseconds)')
plt.grid(True)

plt.savefig('y scale log linegraph_sorting_algorithms')
plt.show()

# %%
import pandas as pd
pd.set_option('precision', 3)

# %%
# Parameters for the pandas DataFrame i.e., formatting the output of the benchmark results
# Labels for rows and columns of the DataFrame
rows = "Bubble Sort", "Selection Sort", "Merge Sort", "Heap Sort", "Counting Sort"  
cols = 100, 250, 500, 750, 1000, 1250, 2500, 3750, 5000, 6250, 7500, 8750, 10000
# Data to place within the DataFrame
output = bubbleBenchmarks, selectionBenchmarks, mergeBenchmarks,heapBenchmarks, countBenchmarks 
# Creation of the DataFrame using the parameters listed above 
df = pd.DataFrame(output, index=list(rows), columns=list(cols))
df.columns.name = 'Input Size'
#Print the DataFrame
df
# Out:
# Input Size      100    250     500     750      1000     1250     2500   \
# Bubble Sort       1.2  7.101  34.703  69.105  121.309  189.214  789.458
# Selection Sort    0.4  2.600  12.201  26.602   46.904   73.707  293.522
# Merge Sort        0.2  0.900   2.700   3.000    4.500    5.600   12.601
# Heap Sort         0.2  1.100   2.500   4.700    6.100    8.301   17.601
# Counting Sort     0.1  0.400   0.500   0.500    0.700    1.000    1.900
#
# Input Size         3750      5000      6250      7500       8750       10000
# Bubble Sort     1748.333  3231.896  5049.497  7503.218  10370.583  13146.455
# Selection Sort   650.850  1198.191  1829.037  2770.859   4291.227   5107.924
# Merge Sort        19.900    26.800    42.003    47.603     54.006     70.404
# Heap Sort         27.401    37.003    48.904    63.206     82.506     94.007
# Counting Sort      2.500     3.801     5.900     5.600      7.901      7.302
